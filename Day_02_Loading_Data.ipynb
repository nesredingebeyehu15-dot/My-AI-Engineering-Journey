# %% [markdown]
# <a href="https://colab.research.google.com/github/nesredingebeyehu15-dot/My-AI-Engineering-Journey/blob/main/Day_02_Loading_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#1. simulate a client file(grade analysis)
#This code creat student_file.csv
#This file is my client file
Student_grading_system="""Name,Grade,subject
nesredin,88,maths
ahmed,100,physics
ekram,93,chemistry
babye,99,biology
habiba,100,cooking"""

with open("student_file.csv","w") as f:f.write(Student_grading_system)
print(f"---file created succesfully:'student_file.csv'---")
#2.Read the CSV ,The most important line ,it creats data frame
df=pd.read_csv("student_file.csv")
print(df.describe())
# Out:
# ---file created succesfully:'student_file.csv'---
#             Grade
# count    5.000000
# mean    96.000000
# std      5.338539
# min     88.000000
# 25%     93.000000
# 50%     99.000000
# 75%    100.000000
# max    100.000000
